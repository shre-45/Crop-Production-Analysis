# %%
import pandas as pd
import numpy as np

# %%
crop_data=pd.read_csv("C:\\Users\\reddy\\OneDrive\\Documents\\Crop Production data.csv")

# %%
crop_data.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
crop_data.shape
# Out:
# (246091, 7)

# %%
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
crop_data.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
crop_data.dropna(subset=["Production"],axis=0,inplace=True)

# %%
crop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242361 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     242361 non-null  object
#  1   District_Name  242361 non-null  object
#  2   Crop_Year      242361 non-null  int64
#  3   Season         242361 non-null  object
#  4   Crop           242361 non-null  object
#  5   Area           242361 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.8+ MB

# %%
crop_data.describe()
# Out:
#            Crop_Year          Area    Production
# count  242361.000000  2.423610e+05  2.423610e+05
# mean     2005.625773  1.216741e+04  5.825034e+05
# std         4.958285  5.085744e+04  1.706581e+07
# min      1997.000000  1.000000e-01  0.000000e+00
# 25%      2002.000000  8.700000e+01  8.800000e+01
# 50%      2006.000000  6.030000e+02  7.290000e+02
# 75%      2010.000000  4.545000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
crop_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Univariate Analysis

# %%
def numerical_univariate_analysis(numerical_data) :
     for col_name in numerical_data:
            print("*"*10, col_name,"*"*10)
            print(numerical_data[col_name].agg(['min','max','mean','median','std','skew','kurt']))
            print()

# %%
numerical_univariate_analysis(crop_data[['Area']])
# Out:
# ********** Area **********
# min       1.000000e-01
# max       8.580100e+06
# mean      1.216741e+04
# median    6.030000e+02
# std       5.085744e+04
# skew      4.776912e+01
# kurt      5.506287e+03
# Name: Area, dtype: float64

# %%
numerical_univariate_analysis(crop_data[['Production']])
# Out:
# ********** Production **********
# min       0.000000e+00
# max       1.250800e+09
# mean      5.825034e+05
# median    7.290000e+02
# std       1.706581e+07
# skew      4.074154e+01
# kurt      1.882113e+03
# Name: Production, dtype: float64

# %%
crop_data['State_Name'].nunique()
# Out:
# 33

# %%
crop_data['State_Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
crop_data['State_Name'].value_counts()
# Out:
# State_Name
# Uttar Pradesh                  33189
# Madhya Pradesh                 22604
# Karnataka                      21079
# Bihar                          18874
# Assam                          14622
# Odisha                         13524
# Tamil Nadu                     13266
# Maharashtra                    12496
# Rajasthan                      12066
# Chhattisgarh                   10368
# West Bengal                     9597
# Andhra Pradesh                  9561
# Gujarat                         8365
# Telangana                       5591
# Uttarakhand                     4825
# Haryana                         4540
# Kerala                          4003
# Nagaland                        3904
# Punjab                          3143
# Meghalaya                       2867
# Arunachal Pradesh               2545
# Himachal Pradesh                2456
# Jammu and Kashmir               1632
# Tripura                         1412
# Manipur                         1266
# ...

# %% [markdown]
# In this data more data was collected from Uttar Pradesh,Madhya Pradesh and Karnataka

# %%
crop_data['District_Name'].nunique()
# Out:
# 646

# %%
crop_data['District_Name'].unique()
# Out:
# array(['NICOBARS', 'NORTH AND MIDDLE ANDAMAN', 'SOUTH ANDAMANS',
#        'ANANTAPUR', 'CHITTOOR', 'EAST GODAVARI', 'GUNTUR', 'KADAPA',
#        'KRISHNA', 'KURNOOL', 'PRAKASAM', 'SPSR NELLORE', 'SRIKAKULAM',
#        'VISAKHAPATANAM', 'VIZIANAGARAM', 'WEST GODAVARI', 'ANJAW',
#        'CHANGLANG', 'DIBANG VALLEY', 'EAST KAMENG', 'EAST SIANG',
#        'KURUNG KUMEY', 'LOHIT', 'LONGDING', 'LOWER DIBANG VALLEY',
#        'LOWER SUBANSIRI', 'NAMSAI', 'PAPUM PARE', 'TAWANG', 'TIRAP',
#        'UPPER SIANG', 'UPPER SUBANSIRI', 'WEST KAMENG', 'WEST SIANG',
#        'BAKSA', 'BARPETA', 'BONGAIGAON', 'CACHAR', 'CHIRANG', 'DARRANG',
#        'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'DIMA HASAO', 'GOALPARA',
#        'GOLAGHAT', 'HAILAKANDI', 'JORHAT', 'KAMRUP', 'KAMRUP METRO',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MARIGAON',
#        'NAGAON', 'NALBARI', 'SIVASAGAR', 'SONITPUR', 'TINSUKIA',
#        'UDALGURI', 'ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI',
# ...

# %%
crop_data['District_Name'].value_counts()
# Out:
# District_Name
# TUMKUR       931
# BELGAUM      924
# BIJAPUR      905
# HASSAN       895
# BELLARY      887
#             ...
# HYDERABAD      8
# KHUNTI         6
# RAMGARH        6
# NAMSAI         1
# MUMBAI         1
# Name: count, Length: 646, dtype: int64

# %%
crop_data['Season'].nunique()
# Out:
# 6

# %%
crop_data["Season"] = crop_data["Season"].str.strip()

# %%
crop_data['Season'].unique()
# Out:
# array(['Kharif', 'Whole Year', 'Autumn', 'Rabi', 'Summer', 'Winter'],
#       dtype=object)

# %%
crop_data['Season'].value_counts()
# Out:
# Season
# Kharif        94283
# Rabi          66160
# Whole Year    56127
# Summer        14811
# Winter         6050
# Autumn         4930
# Name: count, dtype: int64

# %%
crop_data['Crop'].nunique()
# Out:
# 124

# %%
crop_data['Crop'].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Mesta', 'Cowpea(Lobia)',
#        'Lemon', 'Pome Granet', 'Sapota', 'Cabbage', 'Rapeseed &Mustard',
# ...

# %%
crop_data['Crop'].value_counts()
# Out:
# Crop
# Rice                 15082
# Maize                13787
# Moong(Green Gram)    10106
# Urad                  9710
# Sesamum               8821
#                      ...
# Litchi                   6
# Coffee                   6
# Apple                    4
# Peach                    4
# Other Dry Fruit          1
# Name: count, Length: 124, dtype: int64

# %% [markdown]
# The major crops cultivated in India are Rice,Maize and green gram

# %%
crop_data['Crop_Year'].nunique()
# Out:
# 19

# %%
crop_data['Crop_Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 1997, 1998, 1999,
#        2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
crop_data['Crop_Year'].value_counts().sort_index()
# Out:
# Crop_Year
# 1997     8899
# 1998    11262
# 1999    12441
# 2000    13553
# 2001    13293
# 2002    16536
# 2003    17139
# 2004    13858
# 2005    13519
# 2006    13976
# 2007    14269
# 2008    14230
# 2009    13767
# 2010    13793
# 2011    13791
# 2012    13184
# 2013    13475
# 2014    10815
# 2015      561
# Name: count, dtype: int64

# %%
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.boxplot(crop_data.Area)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(crop_data.Production)
plt.show()

# %% [markdown]
# There are lot of outliers in both Area and Production

# %%
import seaborn as sns
sns.set_style("darkgrid")
fi,axs=plt.subplots(1,2,figsize=(20,7))
sns.countplot(x="Season",data=crop_data,ax=axs[0],palette='deep')
sns.countplot(x="Crop_Year",data=crop_data,ax=axs[1],palette='deep')
plt.show()

# %% [markdown]
# More crops were cultivated in kharif season in the year of 2003

# %%
import seaborn as sns
sns.set_style("darkgrid")
plt.figure(figsize=(35,15))
sns.countplot(x="Crop",data=crop_data,palette='deep')
plt.xticks(rotation=90)
plt.xticks(fontsize=15,color='black')
plt.yticks(fontsize=20,color='black')
plt.xlabel("Crop",fontsize=25)
plt.ylabel("Count",fontsize=25)
plt.show()

# %% [markdown]
# The Highest crops are cultivated in India are Rice and Maize

# %% [markdown]
# # Bivariate Analysis

# %%
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
numerical_crop_data = crop_data.select_dtypes(include=[np.number])  
categorical_crop_data = crop_data.select_dtypes(exclude=[np.number])

# %%
numerical_crop_data.corr()
# Out:
#             Crop_Year      Area  Production
# Crop_Year    1.000000 -0.025305    0.006989
# Area        -0.025305  1.000000    0.040587
# Production   0.006989  0.040587    1.000000

# %% [markdown]
# There is no high correlation between Area and Production

# %%
pd.set_option('display.max_rows', None)
pd.crosstab(crop_data['Crop'], crop_data['Season'], normalize='index')
# Out:
# Season                       Autumn    Kharif      Rabi    Summer  Whole Year  \
# Crop
# Apple                      0.000000  0.000000  0.000000  0.000000    1.000000
# Arcanut (Processed)        0.000000  0.000000  0.000000  0.000000    1.000000
# Arecanut                   0.000000  0.010403  0.076723  0.000000    0.912874
# Arhar/Tur                  0.002408  0.896335  0.059390  0.003745    0.033975
# Ash Gourd                  0.000000  0.000000  0.000000  0.000000    1.000000
# Atcanut (Raw)              0.000000  0.000000  0.000000  0.000000    1.000000
# Bajra                      0.000000  0.860755  0.048708  0.061536    0.029002
# Banana                     0.001915  0.041813  0.019151  0.060645    0.874242
# Barley                     0.000000  0.032556  0.955782  0.000000    0.011662
# Bean                       0.000000  1.000000  0.000000  0.000000    0.000000
# Beans & Mutter(Vegetable)  0.000000  0.000000  0.000000  0.000000    1.000000
# ...

# %%
crop_data.groupby('State_Name')['Production'].sum().sort_values(ascending=False).head(10)
# Out:
# State_Name
# Kerala                         9.788005e+10
# Andhra Pradesh                 1.732459e+10
# Tamil Nadu                     1.207644e+10
# Uttar Pradesh                  3.234493e+09
# Assam                          2.111752e+09
# West Bengal                    1.397904e+09
# Maharashtra                    1.263641e+09
# Karnataka                      8.634298e+08
# Andaman and Nicobar Islands    7.182232e+08
# Punjab                         5.863850e+08
# Name: Production, dtype: float64

# %%
crop_data.groupby('District_Name')['Production'].sum().sort_values(ascending=False).head(10)
# Out:
# District_Name
# KOZHIKODE             1.528074e+10
# MALAPPURAM            1.451840e+10
# THIRUVANANTHAPURAM    1.002271e+10
# THRISSUR              9.923508e+09
# KANNUR                9.783432e+09
# EAST GODAVARI         8.271057e+09
# KASARAGOD             7.732217e+09
# KOLLAM                7.151945e+09
# PALAKKAD              6.369382e+09
# ERNAKULAM             5.021649e+09
# Name: Production, dtype: float64

# %%
sns.heatmap(numerical_crop_data.corr(),annot=True,cmap='crest')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no high correlation between Area and Production

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize= (15,15))
sns.barplot(x=crop_data['Production'],y= crop_data["State_Name"], orient='h',palette='deep')
plt.show()

# %% [markdown]
# Kerala is the top in crop production from 1997 to 2015 i.e 19 years

# %%
data_explore=crop_data.copy()

# %%
crop_data_season=data_explore.copy()
season = crop_data_season.groupby(by='Season')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
season
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(season.Season, season.Production,errwidth=0)
plt.yscale('log')
plt.title('Seasonal Crops vs Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Seasonal Crops vs Production')

# %% [markdown]
# Top crop categories which shows high production values are Whole Year(Annual growing plants), Kharif and Rabi crops.

# %%
crop=crop_data['Crop']
def cat_crop(crop):
    for i in ['Rice','Maize','Wheat','Barley','Varagu','Other Cereals & Millets','Ragi','Small millets','Bajra','Jowar', 'Paddy','Total foodgrain','Jobster']:
        if crop==i:
            return 'Cereal'
    for i in ['Moong','Urad','Arhar/Tur','Peas & beans','Masoor',
              'Other Kharif pulses','other misc. pulses','Ricebean (nagadal)',
              'Rajmash Kholar','Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
              'Other  Rabi pulses','Other Kharif pulses','Peas & beans (Pulses)','Pulses total','Gram']:
        if crop==i:
            return 'Pulses'
    for i in ['Peach','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon','Pome Granet',
               'Other Citrus Fruit','Water Melon','Jack Fruit','Grapes','Pineapple','Orange',
               'Pome Fruit','Citrus Fruit','Other Fresh Fruits','Mango','Papaya','Coconut','Banana']:
        if crop==i:
            return 'Fruits'
    for i in ['Bean','Lab-Lab','Moth','Guar seed','Soyabean','Horse-gram']:
        if crop==i:
            return 'Beans'
    for i in ['Turnip','Peas','Beet Root','Carrot','Yam','Ribed Guard','Ash Gourd ','Pump Kin','Redish','Snak Guard','Bottle Gourd',
              'Bitter Gourd','Cucumber','Drum Stick','Cauliflower','Beans & Mutter(Vegetable)','Cabbage',
              'Bhindi','Tomato','Brinjal','Khesari','Sweet potato','Potato','Onion','Tapioca','Colocosia']:
              if crop==i:
                return 'Vegetables'
    for i in ['Perilla','Ginger','Cardamom','Black pepper','Dry ginger','Garlic','Coriander','Turmeric','Dry chillies','Cond-spcs other']:
        if crop==i:
            return 'spices'
    for i in ['other fibres','Kapas','Jute & mesta','Jute','Mesta','Cotton(lint)','Sannhamp']:
        if crop==i:
            return 'fibres'
    for i in ['Arcanut (Processed)','Atcanut (Raw)','Cashewnut Processed','Cashewnut Raw','Cashewnut','Arecanut','Groundnut']:
        if crop==i:
            return 'Nuts'
    for i in ['other oilseeds','Safflower','Niger seed','Castor seed','Linseed','Sunflower','Rapeseed &Mustard','Sesamum','Oilseeds total']:
        if crop==i:
            return 'oilseeds'
    for i in ['Tobacco','Coffee','Tea','Sugarcane','Rubber']:
        if crop==i:
            return 'Commercial'

crop_data['cat_crop']=crop_data['Crop'].apply(cat_crop)

# %%
crop_data['cat_crop'].value_counts()
# Out:
# cat_crop
# Cereal        63283
# Pulses        40898
# oilseeds      33801
# Vegetables    23154
# spices        21638
# Nuts          11472
# Commercial    10561
# fibres         9785
# Beans          9115
# Fruits         6153
# Name: count, dtype: int64

# %%
crop = crop_data.groupby(by='cat_crop')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(crop.cat_crop,crop.Production,errwidth=0)
plt.yscale('log')
plt.title('Crops vs Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Crops vs Production')

# %% [markdown]
# commercial and cereal crops has more production

# %%
#Zone-Wise Production - 1997-2014
north_india = ['Jammu and Kashmir', 'Punjab', 'Himachal Pradesh', 'Haryana', 'Uttarakhand', 'Uttar Pradesh', 'Chandigarh']
east_india = ['Bihar', 'Odisha', 'Jharkhand', 'West Bengal']
south_india = ['Andhra Pradesh', 'Karnataka', 'Kerala' ,'Tamil Nadu', 'Telangana']
west_india = ['Rajasthan' , 'Gujarat', 'Goa','Maharashtra']
central_india = ['Madhya Pradesh', 'Chhattisgarh']
north_east_india = ['Assam', 'Sikkim', 'Nagaland', 'Meghalaya', 'Manipur', 'Mizoram', 'Tripura', 'Arunachal Pradesh']
ut_india = ['Andaman and Nicobar Islands', 'Dadra and Nagar Haveli', 'Puducherry']

# %%
def get_zonal_names(row):
    if row['State_Name'].strip() in north_india:
        val = 'North Zone'
    elif row['State_Name'].strip()  in south_india:
        val = 'South Zone'
    elif row['State_Name'].strip()  in east_india:
        val = 'East Zone'
    elif row['State_Name'].strip()  in west_india:
        val = 'West Zone'
    elif row['State_Name'].strip()  in central_india:
        val = 'Central Zone'
    elif row['State_Name'].strip()  in north_east_india:
        val = 'NE Zone'
    elif row['State_Name'].strip()  in ut_india:
        val = 'Union Terr'
    else:
        val = 'No Value'
    return val

crop_data['Zones'] = crop_data.apply(get_zonal_names, axis=1)
crop_data['Zones'].unique()
# Out:
# array(['Union Terr', 'South Zone', 'NE Zone', 'East Zone', 'North Zone',
#        'Central Zone', 'West Zone'], dtype=object)

# %%
crop_data['Zones'].value_counts()
# Out:
# Zones
# South Zone      53500
# North Zone      49874
# East Zone       43261
# West Zone       33134
# Central Zone    32972
# NE Zone         28284
# Union Terr       1336
# Name: count, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(15,10))
sns.barplot(crop_data.Zones.sort_values(ascending=True), crop_data.Production)
plt.yscale('log')
plt.title('Zone-Wise Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Zone-Wise Production')

# %% [markdown]
# Top Zone in Production is South Zone

# %%
south_zone = crop_data[(crop_data["Zones"] == 'South Zone')]
fig,ax = plt.subplots(figsize=(15,10))
sns.barplot(south_zone.State_Name, south_zone.Production,errwidth=0)
plt.yscale('log')
plt.title('Southern-Zone Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Southern-Zone Production')

# %% [markdown]
# Top production in South India states are Kerala, Andhra Pradesh and Tamil Nadu

# %%
crop = crop_data.groupby(by='Crop')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)
crop 
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(crop.Crop, crop.Production)
plt.yscale('log')
plt.title('Overall Crops vs Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Overall Crops vs Production')

# %% [markdown]
# Top Crops Production wise are: Coconut, Sugarcane and Rice

# %%
plt.tick_params(labelsize=10)
crop_data.groupby("Crop_Year")["Production"].agg("sum").plot.bar()
plt.title("Yearwise Production")
# Out:
# Text(0.5, 1.0, 'Yearwise Production')

# %% [markdown]
# High productive years are 2011, 2013 and 2014.

# %%
df1=crop_data["cat_crop"].value_counts()
plt.figure(figsize=(6,2))
df1.plot(radius=3,kind="pie",autopct="%1.1f",pctdistance=0.6)
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# Top crop categories are Cereal, Pulses and Oilseeds.

# %%
df_2 = pd.crosstab(crop_data['State_Name'],crop_data['cat_crop'])
df_2
# Out:
# cat_crop                     Beans  Cereal  Commercial  Fruits  Nuts  Pulses  \
# State_Name
# Andaman and Nicobar Islands      0      20          15      16    37       9
# Andhra Pradesh                 386    2264         474     502   674    1336
# Arunachal Pradesh               26    1021         168       0    26      67
# Assam                            0    2952         854     920   400    2234
# Bihar                          280    6108         756     226   130    3731
# Chandigarh                       0      39           0       0     0      14
# Chhattisgarh                   646    1805         316     264   261    2087
# Dadra and Nagar Haveli           0     116          12       9     9      64
# Goa                              0      62          22      16    47      32
# Gujarat                        403    2466         372     157   683    1521
# Haryana                        108    1427         259      52   126     860
# ...

# %%
df_2.plot(kind='bar', stacked=True, figsize = (16,8))
# Out:
# <AxesSubplot:xlabel='State_Name'>

# %% [markdown]
# Uttar Pradesh is topping in producing more crop categories than any other Indian state.

# %%
North_zone =  crop_data[(crop_data["Zones"] == 'North Zone')]
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(North_zone.State_Name, North_zone.Production,errwidth=0)
plt.xticks(rotation=75);
plt.yscale('log')
plt.title('Northern-Zone Production')

North_zone.groupby(by='State_Name')['Production'].sum().reset_index().sort_values(by='Production', ascending=False)
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#            State_Name    Production
# 5       Uttar Pradesh  3.234493e+09
# 4              Punjab  5.863850e+08
# 1             Haryana  3.812739e+08
# 6         Uttarakhand  1.321774e+08
# 2    Himachal Pradesh  1.780517e+07
# 3  Jammu and Kashmir   1.329102e+07
# 0          Chandigarh  6.395650e+04

# %% [markdown]
# Production wise top states of North zone are:Punjab,Uttar Pradesh,Haryana

# %%
df3 = North_zone.groupby(by='Crop')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(df3.Crop, df3.Production,errwidth=0)
plt.xticks(rotation=75);
plt.yscale('log')
plt.title('North Zone Crops vs Production')
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'North Zone Crops vs Production')

# %% [markdown]
# Top crops of these states are:Sugarcane,Wheat and Rice

# %%
coc_df = crop_data[crop_data["Crop"]=="Coconut "]
print(coc_df.shape)
coc_df[:3]
# Out:
# (1958, 9)
#                      State_Name District_Name  Crop_Year      Season  \
# 5   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 14  Andaman and Nicobar Islands      NICOBARS       2001  Whole Year
# 23  Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
#
#         Crop     Area  Production cat_crop       Zones
# 5   Coconut   18168.0  65100000.0     None  Union Terr
# 14  Coconut   18190.0  64430000.0     None  Union Terr
# 23  Coconut   18240.0  67490000.0     None  Union Terr

# %%
top_coc_pro_dis = coc_df.groupby("District_Name")["Production"].sum().reset_index().sort_values(
    by='Production',ascending=False)
top_coc_pro_dis[:5]
sum_max = top_coc_pro_dis["Production"].sum()
top_coc_pro_dis["precent_of_pro"] = top_coc_pro_dis["Production"].map(lambda x:(x/sum_max)*100)
top_coc_pro_dis[:5]
# Out:
#           District_Name    Production  precent_of_pro
# 77            KOZHIKODE  1.527871e+10       11.754512
# 86           MALAPPURAM  1.451252e+10       11.165052
# 129  THIRUVANANTHAPURAM  1.001337e+10        7.703678
# 131            THRISSUR  9.920739e+09        7.632416
# 64               KANNUR  9.780310e+09        7.524379

# %%
plt.figure(figsize=(18,12))
sns.barplot("District_Name","Production",data=top_coc_pro_dis[:5])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# KOZHIKODE and MALAPPURAM districts are highest in coconut production

# %%
plt.figure(figsize=(15,10))
sns.barplot("Crop_Year","Production",data=coc_df)
plt.xticks(rotation=45)
#plt.legend(rice_df['State_Name'].unique())
plt.show()
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Year wise coconut cultivation is strong and increasing.In 2014 the coconut production was more
